# %%
import numpy as np
import pandas as pd
import time
from sklearn import preprocessing
from sklearn import cross_validation
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.metrics import f1_score, confusion_matrix
from sklearn import grid_search
from sklearn.metrics import f1_score
from sklearn.metrics import make_scorer

# %%
def train_classifier(clf, X_train, y_train):
    print "Training {}...".format(clf.__class__.__name__)
    start = time.time()
    clf.fit(X_train, y_train)
    end = time.time()
    print "Done!\nTraining time (secs): {:.3f}".format(end - start)

# %%
def predict_labels(clf, features, target):
    print "Predicting labels using {}...".format(clf.__class__.__name__)
    start = time.time()
    y_pred = clf.predict(features)
    end = time.time()
    print "Done!\nPrediction time (secs): {:.3f}".format(end - start)
    print "Confusion Matrix:\n {}".format(confusion_matrix(target, y_pred))
    return f1_score(target.values, y_pred, pos_label=100)

# %%
# Ready csv with game data
game_data = pd.read_csv('gameData_15Minutes.csv',keep_default_na=False)

# %%
# Get the Accuracy for the Naive Approach (the team with more gold wins)
def naive_accuracy(X,y):    
    blue = len(X[X['blueGold']>X['redGold']][y==100])
    red  = len(X[X['blueGold']<X['redGold']][y==200])
    games = len(X)

    print 'Naive Accuracy: {:.2f}%'.format(float(blue+red)/games*100)

# %%
# Data Set for learning
X_all = game_data[game_data.columns[-28:]]
y_all = game_data['winner']

# Normalize Data 
#X_all = preprocessing.normalize(X_all, norm='l2')

# Separate data into train/test samples
num_all = len(game_data)
num_train = int(num_all*0.75)  # 75% of the data as train set
num_test = num_all - num_train
X_train, X_test, y_train, y_test = cross_validation.train_test_split(X_all,y_all,test_size=num_test,random_state=0)
print "Training set: {} samples".format(X_train.shape[0])
print "Test set: {} samples".format(X_test.shape[0])
print X_all.columns
# Out:
# Training set: 64369 samples
# Test set: 21457 samples
# Index([u'blueGold', u'redGold', u'blueDragons', u'blueRiftHerald',
#        u'redDragons', u'redRiftHerald', u'blueWards', u'redWards',
#        u'blueDestroyedWards', u'redDestroyedWards', u'blueTopTurrets',
#        u'blueMidTurrets', u'blueBotTurrets', u'redTopTurrets',
#        u'redMidTurrets', u'redBotTurrets', u'blueInhibitor', u'redInhibitor',
#        u'blueKills', u'blueAssists', u'redKills', u'redAssists', u'blueCs',
#        u'blueJg', u'blueXp', u'redCs', u'redJg', u'redXp'],
#       dtype='object')

# %%
# Train Classifier
clf = RandomForestClassifier(n_estimators=1000, max_features=0.5, max_depth=5)
train_classifier(clf, X_train, y_train)  
print clf

# Evaluate Classifier's performance on Train Data
train_f1_score = predict_labels(clf, X_train, y_train)
print "F1 score for training set: {}".format(train_f1_score)

# Evaluate Classifier's performance on Test Data
print "F1 score for test set: {}".format(predict_labels(clf, X_test, y_test))
# Out:
# Training RandomForestClassifier...
# Done!
# Training time (secs): 102.727
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=5, max_features=0.5, max_leaf_nodes=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=1000, n_jobs=1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)
# Predicting labels using RandomForestClassifier...
# Done!
# Prediction time (secs): 4.992
# Confusion Matrix:
#  [[24292  7711]
#  [ 7663 24703]]
# F1 score for training set: 0.759623502924
# Predicting labels using RandomForestClassifier...
# Done!
# Prediction time (secs): 1.726
# Confusion Matrix:
#  [[7934 2704]
#  [2615 8204]]
# F1 score for test set: 0.748949827725

# %%
naive_accuracy(X_test,y_test)
# Out:
# Naive Accuracy: 75.12%

# %%
print game_data[game_data['blueGold']>game_data['redGold']][game_data['winner']==200]
# Out:
#           matchId  matchVersion region                      queueType  \
# 12     2090631173     6.2.0.247     NA  TEAM_BUILDER_DRAFT_RANKED_5x5
# 50     2103760187     6.3.0.240     NA  TEAM_BUILDER_DRAFT_RANKED_5x5
# 52     2104346549     6.3.0.240     NA  TEAM_BUILDER_DRAFT_RANKED_5x5
# 63     2104881738     6.3.0.240     NA  TEAM_BUILDER_DRAFT_RANKED_5x5
# 67     2105710124     6.3.0.240     NA  TEAM_BUILDER_DRAFT_RANKED_5x5
# 71     2105840008     6.3.0.240     NA  TEAM_BUILDER_DRAFT_RANKED_5x5
# 108    2109788545     6.4.0.249     NA  TEAM_BUILDER_DRAFT_RANKED_5x5
# 133    2111230700     6.4.0.257     NA  TEAM_BUILDER_DRAFT_RANKED_5x5
# 137    2111380022     6.4.0.257     NA  TEAM_BUILDER_DRAFT_RANKED_5x5
# 145    2111977774     6.4.0.257     NA  TEAM_BUILDER_DRAFT_RANKED_5x5
# 151    2112041510     6.4.0.257     NA  TEAM_BUILDER_DRAFT_RANKED_5x5
# 173    2112659213     6.4.0.257     NA  TEAM_BUILDER_DRAFT_RANKED_5x5
# 182    2113568612     6.4.0.259     NA  TEAM_BUILDER_DRAFT_RANKED_5x5
# 185    2113574345     6.4.0.259     NA  TEAM_BUILDER_DRAFT_RANKED_5x5
# 189    2113647181     6.4.0.259     NA  TEAM_BUILDER_DRAFT_RANKED_5x5
# 191    2113692975     6.4.0.259     NA  TEAM_BUILDER_DRAFT_RANKED_5x5
# 196    2113865750     6.4.0.259     NA  TEAM_BUILDER_DRAFT_RANKED_5x5
# 204    2114024758     6.4.0.259     NA  TEAM_BUILDER_DRAFT_RANKED_5x5
# 210    2114165421     6.4.0.259     NA  TEAM_BUILDER_DRAFT_RANKED_5x5
# 218    2114227532     6.4.0.259     NA  TEAM_BUILDER_DRAFT_RANKED_5x5
# 220    2114239317     6.4.0.259     NA  TEAM_BUILDER_DRAFT_RANKED_5x5
# 227    2114438358     6.4.0.259     NA  TEAM_BUILDER_DRAFT_RANKED_5x5
# 231    2114642190     6.4.0.259     NA  TEAM_BUILDER_DRAFT_RANKED_5x5
# 235    2114827655     6.4.0.259     NA  TEAM_BUILDER_DRAFT_RANKED_5x5
# 248    2115455178     6.4.0.259     NA  TEAM_BUILDER_DRAFT_RANKED_5x5
# 249    2115646953     6.4.0.259     NA  TEAM_BUILDER_DRAFT_RANKED_5x5
# 253    2116251385     6.4.0.259     NA  TEAM_BUILDER_DRAFT_RANKED_5x5
# 259    2116413834     6.4.0.259     NA  TEAM_BUILDER_DRAFT_RANKED_5x5
# 269    2116772474     6.4.0.259     NA  TEAM_BUILDER_DRAFT_RANKED_5x5
# 278    2117047814     6.4.0.259     NA  TEAM_BUILDER_DRAFT_RANKED_5x5
# ...           ...           ...    ...                            ...
# 85625   312561790  6.6.138.2102    LAS  TEAM_BUILDER_DRAFT_RANKED_5x5
# 85626   312561805  6.6.138.2102    LAS  TEAM_BUILDER_DRAFT_RANKED_5x5
# 85641   312561990  6.6.138.2102    LAS  TEAM_BUILDER_DRAFT_RANKED_5x5
# 85644   312562012  6.6.138.2102    LAS  TEAM_BUILDER_DRAFT_RANKED_5x5
# 85648   312562062  6.6.138.2102    LAS  TEAM_BUILDER_DRAFT_RANKED_5x5
# 85651   312562135  6.6.138.2102    LAS  TEAM_BUILDER_DRAFT_RANKED_5x5
# 85652   312562139  6.6.138.2102    LAS  TEAM_BUILDER_DRAFT_RANKED_5x5
# 85656   312562196  6.6.138.2102    LAS  TEAM_BUILDER_DRAFT_RANKED_5x5
# 85661   312562285  6.6.138.2102    LAS  TEAM_BUILDER_DRAFT_RANKED_5x5
# 85668   312562454  6.6.138.2102    LAS  TEAM_BUILDER_DRAFT_RANKED_5x5
# 85702   312563167  6.6.138.2102    LAS  TEAM_BUILDER_DRAFT_RANKED_5x5
# 85706   312563241  6.6.138.2102    LAS  TEAM_BUILDER_DRAFT_RANKED_5x5
# 85719   312563560  6.6.138.2102    LAS  TEAM_BUILDER_DRAFT_RANKED_5x5
# 85724   312563879  6.6.138.2102    LAS  TEAM_BUILDER_DRAFT_RANKED_5x5
# 85725   312563985  6.6.138.2102    LAS  TEAM_BUILDER_DRAFT_RANKED_5x5
# 85733   312564214  6.6.138.2102    LAS  TEAM_BUILDER_DRAFT_RANKED_5x5
# 85736   312564255  6.6.138.2102    LAS  TEAM_BUILDER_DRAFT_RANKED_5x5
# 85742   312564468  6.6.138.2102    LAS  TEAM_BUILDER_DRAFT_RANKED_5x5
# 85743   312564476  6.6.138.2102    LAS  TEAM_BUILDER_DRAFT_RANKED_5x5
# 85744   312564510  6.6.138.2102    LAS  TEAM_BUILDER_DRAFT_RANKED_5x5
# 85745   312564562  6.6.138.2102    LAS  TEAM_BUILDER_DRAFT_RANKED_5x5
# 85766   312565234  6.6.138.2102    LAS  TEAM_BUILDER_DRAFT_RANKED_5x5
# 85771   312565435  6.6.138.2102    LAS  TEAM_BUILDER_DRAFT_RANKED_5x5
# 85778   312565681  6.6.138.2102    LAS  TEAM_BUILDER_DRAFT_RANKED_5x5
# 85785   312566167  6.6.138.2102    LAS  TEAM_BUILDER_DRAFT_RANKED_5x5
# 85794   312566504  6.6.138.2102    LAS  TEAM_BUILDER_DRAFT_RANKED_5x5
# 85810   312567384  6.6.138.2102    LAS  TEAM_BUILDER_DRAFT_RANKED_5x5
# 85813   312567658  6.6.138.2102    LAS  TEAM_BUILDER_DRAFT_RANKED_5x5
# 85817   312568021  6.6.138.2102    LAS  TEAM_BUILDER_DRAFT_RANKED_5x5
# 85819   312568133  6.6.138.2102    LAS  TEAM_BUILDER_DRAFT_RANKED_5x5
#
#              matchCreation  matchDuration  winner  blueGold  redGold  \
# 12     2016-02-06 21:29:51             46     200     23885    22792
# 50     2016-02-21 06:52:05             29     200     24375    23703
# 52     2016-02-21 21:01:30             32     200     23308    23279
# 63     2016-02-22 18:11:49             36     200     26320    24747
# 67     2016-02-23 14:59:46             37     200     25153    25023
# 71     2016-02-23 20:47:35             30     200     26172    22356
# 108    2016-02-28 02:41:03             36     200     24930    22822
# 133    2016-02-29 20:57:27             35     200     25695    23638
# 137    2016-03-01 00:07:21             42     200     25145    24695
# 145    2016-03-01 18:35:24             38     200     25437    23089
# 151    2016-03-01 19:29:06             45     200     23677    21360
# 173    2016-03-02 19:49:11             49     200     26129    21791
# 182    2016-03-03 16:29:16             34     200     24685    23749
# 185    2016-03-03 15:26:40             33     200     26224    25866
# 189    2016-03-03 18:07:23             31     200     24213    23333
# 191    2016-03-03 18:57:49             30     200     27968    25892
# 196    2016-03-03 22:41:29             43     200     24063    21128
# 204    2016-03-04 01:24:06             32     200     23773    22373
# 210    2016-03-04 03:50:29             32     200     27407    26134
# 218    2016-03-04 06:44:06             27     200     27693    23274
# 220    2016-03-04 07:43:59             40     200     25693    23959
# 227    2016-03-04 16:14:38             40     200     22246    21496
# 231    2016-03-04 17:01:38             40     200     26213    22043
# 235    2016-03-04 21:44:21             33     200     25033    23684
# 248    2016-03-05 13:28:24             44     200     24081    23561
# 249    2016-03-05 17:51:46             26     200     24829    24626
# 253    2016-03-05 23:27:41             36     200     25758    23819
# 259    2016-03-06 02:21:24             31     200     28155    26704
# 269    2016-03-06 15:28:46             32     200     24230    23485
# 278    2016-03-06 20:21:19             46     200     22994    22553
# ...                    ...            ...     ...       ...      ...
# 85625  2016-03-30 08:41:28             39     200     23383    21973
# 85626  2016-03-30 08:46:09             49     200     21883    20619
# 85641  2016-03-30 09:27:25             54     200     22692    22478
# 85644  2016-03-30 09:30:52             37     200     26354    22452
# 85648  2016-03-30 09:41:35             39     200     27363    22083
# 85651  2016-03-30 09:53:52             51     200     24295    20118
# 85652  2016-03-30 09:55:17             42     200     22901    22594
# 85656  2016-03-30 10:03:51             41     200     21996    21719
# 85661  2016-03-30 10:13:58             38     200     22461    20768
# 85668  2016-03-30 10:37:26             40     200     23300    20794
# 85702  2016-03-30 11:45:06             31     200     23467    21211
# 85706  2016-03-30 11:51:44             31     200     23261    22429
# 85719  2016-03-30 12:15:16             28     200     22160    22070
# 85724  2016-03-30 12:39:58             33     200     23661    21408
# 85725  2016-03-30 12:48:01             42     200     19788    19740
# 85733  2016-03-30 13:04:30             46     200     25277    22118
# 85736  2016-03-30 13:08:00             40     200     24934    24802
# 85742  2016-03-30 13:21:15             40     200     21769    20645
# 85743  2016-03-30 13:21:37             25     200     21241    20164
# 85744  2016-03-30 13:22:39             35     200     27228    21365
# 85745  2016-03-30 13:26:04             26     200     22245    21617
# 85766  2016-03-30 14:02:49             42     200     22750    20182
# 85771  2016-03-30 14:12:06             34     200     24858    20286
# 85778  2016-03-30 14:22:07             37     200     22648    20541
# 85785  2016-03-30 14:42:34             36     200     22683    20643
# 85794  2016-03-30 14:57:08             55     200     22421    18817
# 85810  2016-03-30 15:31:50             36     200     24071    21541
# 85813  2016-03-30 15:42:52             43     200     23703    22307
# 85817  2016-03-30 15:55:46             34     200     23815    23154
# 85819  2016-03-30 15:58:32             27     200     26220    25883
#
#        blueDragons  ...    blueKills  blueAssists  redKills  redAssists  \
# 12               0  ...            9            7         4           8
# 50               0  ...            6            8         2           1
# 52               0  ...            6           10         6           4
# 63               0  ...            9            9        12          16
# 67               0  ...            9           15         9          16
# 71               0  ...           10            7         3           3
# 108              0  ...           10           13         7           9
# 133              1  ...            8            9        10          10
# 137              0  ...            6            9         9          11
# 145              1  ...           11           15         8          11
# 151              0  ...            9            4         5           3
# 173              0  ...            9           12         3           5
# 182              1  ...            8           11         9          14
# 185              0  ...            9           18        10          14
# 189              1  ...            8           13         6           5
# 191              0  ...           13           11        11          12
# 196              1  ...            7           14         2           1
# 204              1  ...            5            3         3           3
# 210              0  ...            9           16         9          18
# 218              0  ...            9           13         7          11
# 220              0  ...           10           11         5           6
# 227              0  ...            6            5         6           5
# 231              0  ...            8            4         6          11
# 235              0  ...            6            6         7           9
# 248              0  ...            9            9         8           9
# 249              0  ...            7            6        12           8
# 253              0  ...           10            9        10          13
# 259              1  ...           16           20        13          19
# 269              0  ...            7            6         8           8
# 278              2  ...            5            6         5           8
# ...            ...  ...          ...          ...       ...         ...
# 85625            0  ...            6            9         9           6
# 85626            1  ...            4            2         3           4
# 85641            1  ...            7            5         7           8
# 85644            0  ...            9            6         2           2
# 85648            0  ...           13           15         8          11
# 85651            0  ...            7            8         2           2
# 85652            0  ...            7            3         8          13
# 85656            0  ...            7            7         5           4
# 85661            0  ...            6            6         2           1
# 85668            0  ...            7            8         5           7
# 85702            0  ...            5            5         4           5
# 85706            1  ...            8           11        10          13
# 85719            0  ...            2            3         3           2
# 85724            0  ...            8            9         5           3
# 85725            0  ...            2            1         3           1
# 85733            0  ...            8            9         5           3
# 85736            0  ...            7            8        12          11
# 85742            0  ...            7            7         4           3
# 85743            1  ...            3            1         4           5
# 85744            0  ...           11           15         7          11
# 85745            0  ...            6            8         2           4
# 85766            0  ...            7            9         2           2
# 85771            1  ...           12           12         2           0
# 85778            1  ...            5            4         2           3
# 85785            1  ...            6            6         4           3
# 85794            1  ...            7            9         5           3
# 85810            1  ...            6            6         6           4
# 85813            1  ...            9           12         5           8
# 85817            0  ...            5            4         7           7
# 85819            0  ...            8            2        12          18
#
#        blueCs  blueJg  blueXp  redCs  redJg  redXp
# 12        306      43   28725    314     50  28314
# 50        351      52   29661    411     60  30383
# 52        284      56   27951    317     51  26434
# 63        301      79   31250    274     45  26348
# 67        303      54   27006    301     40  26966
# 71        319      58   29144    338     42  25671
# 108       333      43   28018    291     53  26168
# 133       313      51   30313    291     61  29172
# 137       346      46   27684    333     47  29466
# 145       319      41   28536    291     44  29412
# 151       337      46   27097    266     31  24972
# 173       318      41   27944    298     61  27479
# 182       358      42   29049    336     57  29574
# 185       344      52   28272    345     58  29695
# 189       375      55   28823    361     48  28858
# 191       333      44   30162    280     60  29996
# 196       314      55   29148    320     49  25424
# 204       374      52   28364    335     45  28338
# 210       343      43   27969    322     50  28638
# 218       282      55   28728    269     45  25946
# 220       322      60   30465    332     48  27213
# 227       290      43   26507    280     40  25695
# 231       335      61   29113    301     45  26376
# 235       382      49   29890    335     58  29773
# 248       281      41   26348    263     51  26815
# 249       338      64   30082    322     32  27764
# 253       311      68   31262    308     30  27433
# 259       285      57   28247    271     44  28005
# 269       336      46   29265    326     45  30576
# 278       311      63   27134    331     35  26008
# ...       ...     ...     ...    ...    ...    ...
# 85625     257      28   26451    235     48  27533
# 85626     344      53   28109    295     50  28165
# 85641     313      55   29490    317     40  28637
# 85644     361      35   30227    274     56  26814
# 85648     322      59   29911    269     44  25966
# 85651     333      49   29556    331     47  25524
# 85652     289      46   26769    281     33  27036
# 85656     291      44   28157    316     44  28634
# 85661     312      42   26761    310     51  27027
# 85668     317      53   27020    296     36  25058
# 85702     321      66   29882    297     52  26942
# 85706     251      57   26110    267     47  26531
# 85719     347      45   28220    370     47  29662
# 85724     308      49   28962    310     56  27943
# 85725     274      34   27343    253     47  27513
# 85733     296      56   26440    284     48  26183
# 85736     289      45   28767    237     56  28681
# 85742     292      47   27396    287     32  26025
# 85743     298      52   27673    283     44  28113
# 85744     311      38   27913    278     50  24174
# 85745     314      54   29823    339     68  29273
# 85766     265      40   27628    272     65  26916
# 85771     298      38   30181    267     46  25142
# 85778     365      35   27317    301     40  26269
# 85785     352      38   28181    312     58  27505
# 85794     225      37   25231    230     22  22612
# 85810     306      45   26427    248     48  27684
# 85813     272      66   28431    280     38  26134
# 85817     346      39   28663    315     40  26740
# 85819     291      51   28927    246     55  28137
#
# [10319 rows x 35 columns]

# %%
print game_data[game_data['blueGold']<game_data['redGold']][game_data['winner']==100]
# Out:
#           matchId  matchVersion region                      queueType  \
# 1      2082080642     6.2.0.238     NA  TEAM_BUILDER_DRAFT_RANKED_5x5
# 4      2085919125     6.2.0.238     NA  TEAM_BUILDER_DRAFT_RANKED_5x5
# 5      2085984147     6.2.0.238     NA  TEAM_BUILDER_DRAFT_RANKED_5x5
# 13     2090933974     6.2.0.247     NA  TEAM_BUILDER_DRAFT_RANKED_5x5
# 29     2098790673     6.3.0.240     NA  TEAM_BUILDER_DRAFT_RANKED_5x5
# 34     2101437978     6.3.0.240     NA  TEAM_BUILDER_DRAFT_RANKED_5x5
# 35     2101677342     6.3.0.240     NA  TEAM_BUILDER_DRAFT_RANKED_5x5
# 39     2102180425     6.3.0.240     NA  TEAM_BUILDER_DRAFT_RANKED_5x5
# 42     2102273654     6.3.0.240     NA  TEAM_BUILDER_DRAFT_RANKED_5x5
# 57     2104518286     6.3.0.240     NA  TEAM_BUILDER_DRAFT_RANKED_5x5
# 64     2104886590     6.3.0.240     NA  TEAM_BUILDER_DRAFT_RANKED_5x5
# 68     2105769741     6.3.0.240     NA  TEAM_BUILDER_DRAFT_RANKED_5x5
# 70     2105795120     6.3.0.240     NA  TEAM_BUILDER_DRAFT_RANKED_5x5
# 83     2107580915     6.4.0.248     NA  TEAM_BUILDER_DRAFT_RANKED_5x5
# 88     2107908000     6.4.0.249     NA  TEAM_BUILDER_DRAFT_RANKED_5x5
# 92     2107993889     6.4.0.249     NA  TEAM_BUILDER_DRAFT_RANKED_5x5
# 110    2109837504     6.4.0.249     NA  TEAM_BUILDER_DRAFT_RANKED_5x5
# 141    2111548889     6.4.0.257     NA  TEAM_BUILDER_DRAFT_RANKED_5x5
# 149    2111993783     6.4.0.257     NA  TEAM_BUILDER_DRAFT_RANKED_5x5
# 164    2112538861     6.4.0.257     NA  TEAM_BUILDER_DRAFT_RANKED_5x5
# 165    2112541894     6.4.0.257     NA  TEAM_BUILDER_DRAFT_RANKED_5x5
# 170    2112616935     6.4.0.257     NA  TEAM_BUILDER_DRAFT_RANKED_5x5
# 194    2113746115     6.4.0.259     NA  TEAM_BUILDER_DRAFT_RANKED_5x5
# 205    2114036095     6.4.0.259     NA  TEAM_BUILDER_DRAFT_RANKED_5x5
# 207    2114080590     6.4.0.259     NA  TEAM_BUILDER_DRAFT_RANKED_5x5
# 241    2115182112     6.4.0.259     NA  TEAM_BUILDER_DRAFT_RANKED_5x5
# 260    2116465323     6.4.0.259     NA  TEAM_BUILDER_DRAFT_RANKED_5x5
# 267    2116666276     6.4.0.259     NA  TEAM_BUILDER_DRAFT_RANKED_5x5
# 271    2116795578     6.4.0.259     NA  TEAM_BUILDER_DRAFT_RANKED_5x5
# 274    2116897673     6.4.0.259     NA  TEAM_BUILDER_DRAFT_RANKED_5x5
# ...           ...           ...    ...                            ...
# 85608   312561532  6.6.138.2102    LAS  TEAM_BUILDER_DRAFT_RANKED_5x5
# 85637   312561944  6.6.138.2102    LAS  TEAM_BUILDER_DRAFT_RANKED_5x5
# 85638   312561947  6.6.138.2102    LAS  TEAM_BUILDER_DRAFT_RANKED_5x5
# 85639   312561953  6.6.138.2102    LAS  TEAM_BUILDER_DRAFT_RANKED_5x5
# 85654   312562182  6.6.138.2102    LAS  TEAM_BUILDER_DRAFT_RANKED_5x5
# 85657   312562217  6.6.138.2102    LAS  TEAM_BUILDER_DRAFT_RANKED_5x5
# 85659   312562236  6.6.138.2102    LAS  TEAM_BUILDER_DRAFT_RANKED_5x5
# 85662   312562319  6.6.138.2102    LAS  TEAM_BUILDER_DRAFT_RANKED_5x5
# 85675   312562579  6.6.138.2102    LAS  TEAM_BUILDER_DRAFT_RANKED_5x5
# 85681   312562718  6.6.138.2102    LAS  TEAM_BUILDER_DRAFT_RANKED_5x5
# 85684   312562792  6.6.138.2102    LAS  TEAM_BUILDER_DRAFT_RANKED_5x5
# 85700   312563146  6.6.138.2102    LAS  TEAM_BUILDER_DRAFT_RANKED_5x5
# 85710   312563348  6.6.138.2102    LAS  TEAM_BUILDER_DRAFT_RANKED_5x5
# 85717   312563499  6.6.138.2102    LAS  TEAM_BUILDER_DRAFT_RANKED_5x5
# 85720   312563741  6.6.138.2102    LAS  TEAM_BUILDER_DRAFT_RANKED_5x5
# 85721   312563758  6.6.138.2102    LAS  TEAM_BUILDER_DRAFT_RANKED_5x5
# 85722   312563801  6.6.138.2102    LAS  TEAM_BUILDER_DRAFT_RANKED_5x5
# 85727   312564040  6.6.138.2102    LAS  TEAM_BUILDER_DRAFT_RANKED_5x5
# 85746   312564563  6.6.138.2102    LAS  TEAM_BUILDER_DRAFT_RANKED_5x5
# 85747   312564572  6.6.138.2102    LAS  TEAM_BUILDER_DRAFT_RANKED_5x5
# 85748   312564579  6.6.138.2102    LAS  TEAM_BUILDER_DRAFT_RANKED_5x5
# 85749   312564587  6.6.138.2102    LAS  TEAM_BUILDER_DRAFT_RANKED_5x5
# 85754   312564707  6.6.138.2102    LAS  TEAM_BUILDER_DRAFT_RANKED_5x5
# 85755   312564735  6.6.138.2102    LAS  TEAM_BUILDER_DRAFT_RANKED_5x5
# 85781   312565922  6.6.138.2102    LAS  TEAM_BUILDER_DRAFT_RANKED_5x5
# 85782   312566003  6.6.138.2102    LAS  TEAM_BUILDER_DRAFT_RANKED_5x5
# 85787   312566282  6.6.138.2102    LAS  TEAM_BUILDER_DRAFT_RANKED_5x5
# 85798   312566627  6.6.138.2102    LAS  TEAM_BUILDER_DRAFT_RANKED_5x5
# 85811   312567561  6.6.138.2102    LAS  TEAM_BUILDER_DRAFT_RANKED_5x5
# 85822   312568697  6.6.138.2102    LAS  TEAM_BUILDER_DRAFT_RANKED_5x5
#
#              matchCreation  matchDuration  winner  blueGold  redGold  \
# 1      2016-01-29 01:22:04             29     100     21978    22387
# 4      2016-02-01 21:46:15             36     100     21372    23675
# 5      2016-02-01 22:33:06             39     100     24121    25095
# 13     2016-02-07 03:50:48             46     100     21472    23185
# 29     2016-02-15 18:54:51             32     100     25133    26724
# 34     2016-02-19 00:30:12             35     100     22244    22285
# 35     2016-02-19 04:00:38             39     100     24647    25160
# 39     2016-02-19 19:30:45             31     100     23112    24536
# 42     2016-02-19 22:07:26             34     100     22748    23093
# 57     2016-02-22 00:23:54             44     100     22288    24797
# 64     2016-02-22 19:23:41             26     100     24222    25712
# 68     2016-02-23 18:27:17             23     100     26161    26886
# 70     2016-02-23 19:45:04             38     100     23765    25922
# 83     2016-02-25 19:44:06             27     100     23813    24784
# 88     2016-02-26 04:48:46             40     100     25005    26334
# 92     2016-02-26 08:17:04             34     100     24483    24746
# 110    2016-02-28 04:10:24             38     100     27065    27646
# 141    2016-03-01 07:13:00             40     100     23079    26093
# 149    2016-03-01 17:29:14             33     100     21085    22486
# 164    2016-03-02 16:44:30             30     100     22500    23407
# 165    2016-03-02 14:08:06             29     100     24060    25142
# 170    2016-03-02 18:10:21             37     100     23801    24440
# 194    2016-03-03 20:40:25             31     100     23398    28445
# 205    2016-03-04 01:32:47             30     100     24340    25110
# 207    2016-03-04 01:58:39             37     100     23754    23824
# 241    2016-03-05 02:40:43             25     100     25346    26035
# 260    2016-03-06 03:28:42             39     100     23631    24530
# 267    2016-03-06 12:19:27             27     100     24056    27415
# 271    2016-03-06 15:57:23             41     100     24204    25111
# 274    2016-03-06 18:21:06             22     100     25136    25339
# ...                    ...            ...     ...       ...      ...
# 85608  2016-03-30 05:48:49             45     100     23213    23315
# 85637  2016-03-30 09:18:36             40     100     19808    21559
# 85638  2016-03-30 09:18:38             35     100     22663    24492
# 85639  2016-03-30 09:20:06             30     100     25896    26104
# 85654  2016-03-30 10:02:16             36     100     21153    22731
# 85657  2016-03-30 10:06:14             36     100     23797    26022
# 85659  2016-03-30 10:08:44             36     100     18947    21991
# 85662  2016-03-30 10:21:00             39     100     23610    26173
# 85675  2016-03-30 10:50:39             43     100     19849    22340
# 85681  2016-03-30 11:04:56             30     100     21211    25600
# 85684  2016-03-30 11:13:07             30     100     23805    23843
# 85700  2016-03-30 11:43:02             39     100     20927    24525
# 85710  2016-03-30 12:01:03             36     100     21208    21334
# 85717  2016-03-30 12:12:31             32     100     21284    23362
# 85720  2016-03-30 12:29:49             33     100     20572    25329
# 85721  2016-03-30 12:31:05             50     100     20257    20788
# 85722  2016-03-30 12:35:14             36     100     20277    22083
# 85727  2016-03-30 12:52:41             34     100     22072    23076
# 85746  2016-03-30 13:24:55             28     100     21103    22665
# 85747  2016-03-30 13:26:19             40     100     19681    23710
# 85748  2016-03-30 13:27:07             50     100     22164    23086
# 85749  2016-03-30 13:26:50             48     100     21061    26008
# 85754  2016-03-30 13:33:31             36     100     21441    23683
# 85755  2016-03-30 13:35:23             29     100     22253    22387
# 85781  2016-03-30 14:34:21             30     100     23005    25713
# 85782  2016-03-30 14:36:34             29     100     22528    23863
# 85787  2016-03-30 14:48:07             53     100     25252    27446
# 85798  2016-03-30 15:01:03             38     100     21051    23322
# 85811  2016-03-30 15:38:16             34     100     22406    22940
# 85822  2016-03-30 16:19:06             40     100     22074    26662
#
#        blueDragons  ...    blueKills  blueAssists  redKills  redAssists  \
# 1                0  ...            3            2         6           4
# 4                0  ...            6            4         7           8
# 5                0  ...            8            5         8          10
# 13               1  ...            4            5         5           5
# 29               1  ...           13           15        13          17
# 34               0  ...            1            2         3           1
# 35               0  ...            4            5        10          11
# 39               0  ...            5            4         7           4
# 42               0  ...            2            1         5           3
# 57               0  ...            4            4        10          12
# 64               0  ...            6            6         9           8
# 68               1  ...           13           16        10          10
# 70               0  ...            8           12         8           8
# 83               1  ...            8           11         8           9
# 88               0  ...            7           11         8          14
# 92               0  ...            6            7        10          12
# 110              0  ...           14           25        10          18
# 141              0  ...            4            6        10          16
# 149              1  ...            5            4         6           4
# 164              0  ...            4            4         6           6
# 165              1  ...            6            6         8           6
# 170              0  ...            7            7        11           9
# 194              0  ...            4            7        14          12
# 205              0  ...            6            9         7          10
# 207              0  ...            7            6         5           3
# 241              0  ...            9            9         9          10
# 260              0  ...            5            8         9          17
# 267              0  ...           10           12        10          12
# 271              0  ...            6            7         9           8
# 274              0  ...            9            6         8           9
# ...            ...  ...          ...          ...       ...         ...
# 85608            0  ...           10            9         7          10
# 85637            0  ...            3            0         6           4
# 85638            0  ...            4            2         5           7
# 85639            0  ...           12           10        10          14
# 85654            1  ...            7           11         6          12
# 85657            0  ...           12           18        15          20
# 85659            0  ...            2            3         5           4
# 85662            0  ...            6            5         8           9
# 85675            0  ...            1            1         4          11
# 85681            0  ...            2            1        10          13
# 85684            0  ...            8            5         3           2
# 85700            0  ...            2            1         8           7
# 85710            0  ...            6            5         7           8
# 85717            1  ...            4            4         5          11
# 85720            1  ...            6            8        15          18
# 85721            0  ...            5            8         4           5
# 85722            0  ...            6            2         1           4
# 85727            0  ...            7            8         7           9
# 85746            1  ...            3            3         5           3
# 85747            1  ...            2            3         7           5
# 85748            0  ...            7            7         5           7
# 85749            0  ...            5            6         4           6
# 85754            0  ...            7            7        10          13
# 85755            0  ...            2            1         8          17
# 85781            0  ...            5            3         7           9
# 85782            1  ...            8            9         9           6
# 85787            1  ...           13           11         9           8
# 85798            0  ...            4            3         6           6
# 85811            0  ...            6            8         8           6
# 85822            0  ...            7            8        12          12
#
#        blueCs  blueJg  blueXp  redCs  redJg  redXp
# 1         291      42   27884    345     60  30298
# 4         257      51   25752    301     34  27792
# 5         307      58   30006    288     60  28693
# 13        286      43   24772    290     47  27117
# 29        304      35   27629    278     42  27583
# 34        372      52   28342    397     53  31086
# 35        335      77   29643    344     37  28958
# 39        318      36   29053    319     53  28485
# 42        330      59   28493    350     49  28528
# 57        323      58   27857    319     72  29874
# 64        322      59   29564    342     67  30233
# 68        296      65   30541    364     36  28499
# 70        312      42   27994    358     51  29369
# 83        316      46   28686    319     63  28302
# 88        346      48   29077    331     65  29663
# 92        317      51   28361    280     61  29381
# 110       307      56   28793    309     45  26541
# 141       349      48   26725    341     62  30147
# 149       282      52   25790    325     50  28566
# 164       334      53   27146    315     52  29095
# 165       321      54   28298    343     56  29959
# 170       293      53   27575    303     52  28443
# 194       318      44   27043    329     50  29236
# 205       378      61   29340    359     58  29910
# 207       331      67   30343    367     53  31080
# 241       314      50   28954    324     40  28564
# 260       348      58   28355    319     34  25399
# 267       308      64   30163    378     42  30947
# 271       312      49   27210    339     56  29271
# 274       367      51   31090    342     52  28557
# ...       ...     ...     ...    ...    ...    ...
# 85608     264      41   27985    300     43  27953
# 85637     292      32   24382    297     36  26651
# 85638     308      58   26853    282     36  27700
# 85639     248      41   28587    279     36  27468
# 85654     228      50   25875    262     56  26096
# 85657     215      43   26421    258     28  27193
# 85659     267      40   26292    302     51  30282
# 85662     331      50   30039    349     52  31666
# 85675     295      51   26323    312     32  25738
# 85681     306      51   25885    310     50  28935
# 85684     308      46   28842    309     36  25739
# 85700     306      38   27047    332     48  28902
# 85710     254      49   27171    263     29  27295
# 85717     330      45   26724    280     50  26728
# 85720     258      25   22966    271     33  28600
# 85721     270      39   26767    273     39  25444
# 85722     293       4   23695    279     41  26272
# 85727     293      34   26327    327     47  27654
# 85746     282      65   26736    256     58  27199
# 85747     264      40   24374    356     38  27624
# 85748     281      39   24680    323     47  26671
# 85749     256      47   27100    369     54  30531
# 85754     283      38   25675    327     47  27454
# 85755     305      83   29059    319     31  27668
# 85781     301      51   27437    341     59  30861
# 85782     244      28   23979    257     39  25533
# 85787     291      50   29543    381     39  29570
# 85798     270      55   26023    305     56  26730
# 85811     260      41   28257    335     36  28527
# 85822     247      37   26458    294     49  29995
#
# [10845 rows x 35 columns]

# %%
parameters = {'n_estimators': (100, 500, 1000),
              'max_features': (0.3, 0.4, 0.5, 0.6),
              'max_depth': (5, 6, 7, 8, 9, 10)}
f1 = make_scorer(f1_score, pos_label=100)
clf = RandomForestClassifier()

reg = grid_search.GridSearchCV(clf, parameters, scoring=f1)
reg.fit(X_train,y_train)

print "Best Estimator:"
print reg.best_estimator_
print "F1 score for test sample:"
predict_labels(reg, X_test, y_test)
# Out:
# Best Estimator:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=10, max_features=0.3, max_leaf_nodes=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=500, n_jobs=1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)
# F1 score for test sample:
# Predicting labels using GridSearchCV...
# Done!
# Prediction time (secs): 1.235
# Confusion Matrix:
#  [[6224 2181]
#  [2083 6439]]
# 0.74485399712781231
